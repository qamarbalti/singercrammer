# %%
#NOTE: I have used follwoing website in order to perform the task
#1) https://anaconda.cloud/
#2)https://colab.research.google.com/
#3) https://jupyter.org/
#4) https://chat.openai.com/

import numpy as np
import struct
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# Singer Crammer SVM Implementation
def singer_crammer_svm(X_train, y_train, C, max_iters):
    # This function is a placeholder for your Singer Crammer SVM implementation.
    # You need to complete this function according to the Singer Crammer SVM algorithm.
    # Formulate and solve a convex optimization problem, train binary SVMs for each class, and update model parameters iteratively.
    # You will return the model parameters at the end.

    return model_parameters

# Load your dataset
def load_data():
    # Load the MNIST dataset from binary files
    with open('/content/train-images.idx3-ubyte', 'rb') as f:
        # Read image metadata
        magic, num_images, num_rows, num_cols = struct.unpack('>IIII', f.read(16))
        # Read and reshape the training images
        X_train = np.fromfile(f, dtype=np.uint8).reshape(num_images, num_rows * num_cols)

    with open('/content/train-labels.idx1-ubyte', 'rb') as f:
        # Read label metadata
        magic, num_labels = struct.unpack('>II', f.read(8))

        # Read training labels
        y_train = np.fromfile(f, dtype=np.uint8)

    with open('/content/t10k-images.idx3-ubyte', 'rb') as f:
        # Read image metadata for the test set
        magic, num_images, num_rows, num_cols = struct.unpack('>IIII', f.read(16))
        # Read and reshape the test images
        X_test = np.fromfile(f, dtype=np.uint8).reshape(num_images, num_rows * num_cols)

    with open('/content/t10k-labels.idx1-ubyte', 'rb') as f:
        # Read label metadata for the test set
        magic, num_labels = struct.unpack('>II', f.read(8))
        # Read test labels
        y_test = np.fromfile(f, dtype=np.uint8)

    return X_train, y_train, X_test, y_test

# Load the MNIST dataset
X_train, y_train, X_test, y_test = load_data()

# Display 10 random training images along with their labels
plt.figure(figsize=(10, 4))
for i in range(10):
    index = np.random.randint(0, X_train.shape[0])
    plt.subplot(2, 5, i + 1)
    plt.imshow(X_train[index].reshape(28, 28), cmap='gray')
    plt.title(f"Label: {y_train[index]}")
plt.show()

# Implement PCA for dimensionality reduction with 100 components
pca_100 = PCA(n_components=100)
X_train_pca_100 = pca_100.fit_transform(X_train)
X_test_pca_100 = pca_100.transform(X_test)

# Train an SVM model using scikit-learn with PCA (100 components)
svm = make_pipeline(StandardScaler(), SVC(C=0.01, kernel='linear'))
svm.fit(X_train_pca_100, y_train)

# Make predictions on the test data
y_pred = svm.predict(X_test_pca_100)

# Calculate evaluation metrics for the SVM model with PCA (100 components)
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')
cm = confusion_matrix(y_test, y_pred)

# Print the results for PCA (100 components) using scikit-learn SVM
print("Results for PCA (100 components) using scikit-learn SVM:")
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
print("Confusion Matrix:")
print(cm)

# Implement PCA for dimensionality reduction with 40 components
pca_40 = PCA(n_components=40)
X_train_pca_40 = pca_40.fit_transform(X_train)
X_test_pca_40 = pca_40.transform(X_test)

# Train an SVM model using scikit-learn with PCA (40 components)
svm_40 = make_pipeline(StandardScaler(), SVC(C=0.01, kernel='linear'))
svm_40.fit(X_train_pca_40, y_train)

# Make predictions on the test data using PCA (40 components)
y_pred_40 = svm_40.predict(X_test_pca_40)

# Calculate evaluation metrics for the SVM model with PCA (40 components)
accuracy_40 = accuracy_score(y_test, y_pred_40)
precision_40 = precision_score(y_test, y_pred_40, average='weighted')
recall_40 = recall_score(y_test, y_pred_40, average='weighted')
f1_40 = f1_score(y_test, y_pred_40, average='weighted')
cm_40 = confusion_matrix(y_test, y_pred_40)

# Print the results for PCA (40 components) using scikit-learn SVM
print("Results for PCA (40 components) using scikit-learn SVM:")
print(f"Accuracy: {accuracy_40}")
print(f"Precision: {precision_40}")
print(f"Recall: {recall_40}")
print(f"F1 Score: {f1_40}")
print("Confusion Matrix:")
print(cm_40)
# Out:
# Results for PCA (100 components) using scikit-learn SVM:
# Accuracy: 0.9421
# Precision: 0.9420259356138012
# Recall: 0.9421
# F1 Score: 0.9419701994157004
# Confusion Matrix:
# [[ 968    0    0    1    0    5    3    1    1    1]
#  [   0 1120    2    3    0    1    3    1    5    0]
#  [   7    2  968   11    8    2    8    6   18    2]
#  [   5    0   15  944    0   18    1    9   15    3]
#  [   0    0    8    0  932    1    7    2    2   30]
#  [   7    3    7   38    6  796    8    1   21    5]
#  [   6    2    7    0    2   13  927    0    1    0]
#  [   1    7   21    5   12    0    0  961    0   21]
#  [   4    5    8   22    9   32    8    5  878    3]
#  [   7    6    2   11   31    3    0   17    5  927]]
# Results for PCA (40 components) using scikit-learn SVM:
# Accuracy: 0.9325
# Precision: 0.9324362856775384
# Recall: 0.9325
# F1 Score: 0.9322919880237871
# Confusion Matrix:
# [[ 967    0    1    0    0    7    3    1    1    0]
# ...

# %%
import numpy as np
import struct
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# Singer Crammer SVM Implementation
def singer_crammer_svm(X_train, y_train, C, max_iters):
    # This function is a placeholder for your Singer Crammer SVM implementation.
    # You need to complete this function according to the Singer Crammer SVM algorithm.
    # Formulate and solve a convex optimization problem, train binary SVMs for each class, and update model parameters iteratively.
    # You will return the model parameters at the end.

    return model_parameters

# Load your dataset
def load_data():
    # Load the MNIST dataset from binary files
    with open('/content/train-images.idx3-ubyte', 'rb') as f:
        # Read image metadata
        magic, num_images, num_rows, num_cols = struct.unpack('>IIII', f.read(16))
        # Read and reshape the training images
        X_train = np.fromfile(f, dtype=np.uint8).reshape(num_images, num_rows * num_cols)

    with open('/content/train-labels.idx1-ubyte', 'rb') as f:
        # Read label metadata
        magic, num_labels = struct.unpack('>II', f.read(8))
        # Read training labels
        y_train = np.fromfile(f, dtype=np.uint8)

    with open('/content/t10k-images.idx3-ubyte', 'rb') as f:
        # Read image metadata for the test set
        magic, num_images, num_rows, num_cols = struct.unpack('>IIII', f.read(16))
        # Read and reshape the test images
        X_test = np.fromfile(f, dtype=np.uint8).reshape(num_images, num_rows * num_cols)

    with open('/content/t10k-labels.idx1-ubyte', 'rb') as f:
        # Read label metadata for the test set
        magic, num_labels = struct.unpack('>II', f.read(8))
        # Read test labels
        y_test = np.fromfile(f, dtype=np.uint8)

    return X_train, y_train, X_test, y_test

# Load the MNIST dataset
X_train, y_train, X_test, y_test = load_data()

# Display 10 random training images along with their labels
plt.figure(figsize=(10, 4))
for i in range(10):
    index = np.random.randint(0, X_train.shape[0])
    plt.subplot(2, 5, i + 1)
    plt.imshow(X_train[index].reshape(28, 28), cmap='gray')
    plt.title(f"Label: {y_train[index]}")
plt.show()

# Implement PCA for dimensionality reduction with 100 components
pca_100 = PCA(n_components=100)
X_train_pca_100 = pca_100.fit_transform(X_train)
X_test_pca_100 = pca_100.transform(X_test)

# Train an SVM model using scikit-learn with PCA (100 components)
svm = make_pipeline(StandardScaler(), SVC(C=0.01, kernel='linear'))
svm.fit(X_train_pca_100, y_train)

# Make predictions on the test data
y_pred = svm.predict(X_test_pca_100)

# Calculate evaluation metrics for the SVM model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')
cm = confusion_matrix(y_test, y_pred)

# Print the results for PCA (100 components) using scikit-learn SVM
print("Results for PCA (100 components) using scikit-learn SVM:")
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
print("Confusion Matrix:")
print(cm)

# Singer Crammer SVM Implementation (Complete this part based on your Singer Crammer SVM code)
# C and max_iters can be tuned as hyperparameters.
# model_parameters = singer_crammer_svm(X_train, y_train, C, max_iters)
# y_pred_singer_crammer = predict_singer_crammer_svm(model_parameters, X_test)
# Calculate evaluation metrics for Singer Crammer SVM.
# Report the results.

# Ensure that you complete the Singer Crammer SVM implementation according to your algorithm.
# Out:
# Results for PCA (100 components) using scikit-learn SVM:
# Accuracy: 0.9421
# Precision: 0.942004936121714
# Recall: 0.9421
# F1 Score: 0.9419827173582098
# Confusion Matrix:
# [[ 967    0    1    1    0    6    2    1    1    1]
#  [   0 1121    2    3    0    1    3    1    4    0]
#  [   6    2  965    9    9    3    8    6   21    3]
#  [   5    0   17  940    1   18    1    9   16    3]
#  [   0    1    5    0  935    1    7    2    2   29]
#  [   7    3    6   34    6  800    9    2   21    4]
#  [   7    2    8    0    3   12  925    0    1    0]
#  [   1    7   20    5   13    0    0  961    1   20]
#  [   5    4    8   19    8   34    8    6  880    2]
#  [   7    4    1   11   31    3    0   17    8  927]]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     130   )
#     131   if ephemeral:
# --> 132     _message.blocking_request(
#     133         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
# ...

# %%
import numpy as np
import struct
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# Singer Crammer SVM Implementation
def singer_crammer_svm(X_train, y_train, C, max_iters):
    # This function is a placeholder for your Singer Crammer SVM implementation.
    # You need to complete this function according to the Singer Crammer SVM algorithm.
    # Formulate and solve a convex optimization problem, train binary SVMs for each class, and update model parameters iteratively.
    # You will return the model parameters at the end.

    return model_parameters

# Load your dataset
def load_data():
    # Load the MNIST dataset from binary files
    with open('/content/train-images.idx3-ubyte', 'rb') as f:
        # Read image metadata
        magic, num_images, num_rows, num_cols = struct.unpack('>IIII', f.read(16))
        # Read and reshape the training images
        X_train = np.fromfile(f, dtype=np.uint8).reshape(num_images, num_rows * num_cols)

    with open('/content/train-labels.idx1-ubyte', 'rb') as f:
        # Read label metadata
        magic, num_labels = struct.unpack('>II', f.read(8))
        # Read training labels
        y_train = np.fromfile(f, dtype=np.uint8)

    with open('/content/t10k-images.idx3-ubyte', 'rb') as f:
        # Read image metadata for the test set
        magic, num_images, num_rows, num_cols = struct.unpack('>IIII', f.read(16))
        # Read and reshape the test images
        X_test = np.fromfile(f, dtype=np.uint8).reshape(num_images, num_rows * num_cols)

    with open('/content/t10k-labels.idx1-ubyte', 'rb') as f:
        # Read label metadata for the test set
        magic, num_labels = struct.unpack('>II', f.read(8))
        # Read test labels
        y_test = np.fromfile(f, dtype=np.uint8)

    return X_train, y_train, X_test, y_test

# Load the MNIST dataset
X_train, y_train, X_test, y_test = load_data()

# Display 10 random training images along with their labels
plt.figure(figsize=(10, 4))
for i in range(10):
    index = np.random.randint(0, X_train.shape[0])
    plt.subplot(2, 5, i + 1)
    plt.imshow(X_train[index].reshape(28, 28), cmap='gray')
    plt.title(f"Label: {y_train[index]}")
plt.show()

# Implement PCA for dimensionality reduction with all available components
pca_all = PCA(n_components=None)  # None means keep all components
X_train_pca_all = pca_all.fit_transform(X_train)
X_test_pca_all = pca_all.transform(X_test)

# Train an SVM model using scikit-learn with PCA (all components)
svm = make_pipeline(StandardScaler(), SVC(C=0.01, kernel='linear'))
svm.fit(X_train_pca_all, y_train)

# Make predictions on the test data
y_pred = svm.predict(X_test_pca_all)

# Calculate evaluation metrics for the SVM model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred, average='weighted')
recall = recall_score(y_test, y_pred, average='weighted')
f1 = f1_score(y_test, y_pred, average='weighted')
cm = confusion_matrix(y_test, y_pred)

# Print the results for PCA (all components) using scikit-learn SVM
print("Results for PCA (all components) using scikit-learn SVM:")
print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
print("Confusion Matrix:")
print(cm)

# Optional: Implement Singer Crammer SVM using singer_crammer_svm function and evaluate the results.
# C and max_iters can be tuned as hyperparameters.
# model_parameters = singer_crammer_svm(X_train, y_train, C, max_iters)
# y_pred_singer_crammer = predict_singer_crammer_svm(model_parameters, X_test)
# Calculate evaluation metrics for Singer Crammer SVM.
# Report the results.

# Please complete the Singer Crammer SVM implementation based on the given instructions.
# Out:
# Results for PCA (all components) using scikit-learn SVM:
# Accuracy: 0.9253
# Precision: 0.9253053141160628
# Recall: 0.9253
# F1 Score: 0.9251334071440448
# Confusion Matrix:
# [[ 962    0    2    0    2    4    4    3    2    1]
#  [   0 1112    2    2    1    1    3    1   13    0]
#  [   6    8  947   12   10    3   12    7   26    1]
#  [   4    4   23  920    3   17    2   11   18    8]
#  [   2    3    8    2  926    0    7    2    3   29]
#  [  10    2    2   35   14  780   12    4   29    4]
#  [   5    5   15    1    6   18  900    2    6    0]
#  [   0   12   24    6   13    0    1  952    1   19]
#  [   4   10   10   22   11   28    7   11  861   10]
#  [   6    4    4   15   49    7    0   19   12  893]]
